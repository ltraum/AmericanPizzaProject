# %% [markdown]
# # American Pizza Project — Lloom Theme Induction Experimentation Notebook
#
# This notebook walks through how lloom themebuilding can be applied to the American Pizza Project:
# 1) Setup imports, establish API key, and load dataset
# 2) Preprocess / slice dataset -> Experiment filtering input data to include only particular demographics and questions!
# 3) Induce themes with LLooM  -> Experiment inputting various seed theme terms!
# 4) Review results, create data visualizations

# %% [markdown]
# Setup imports, establish API key, and load dataset

# %%
# If not already done, install packages. May need to restart kernel after.
# !pip install text_lloom pyyaml pandas openpyxl
# !pip install python-dotenv
# !pip install pandas
# Out:
# zsh:1: command not found: pip
# zsh:1: command not found: pip
# zsh:1: command not found: pip

# %%
# Setup: imports used throughout the notebook
import sys
import subprocess
import os
import asyncio
import pandas as pd
import text_lloom.workbench as wb



# Set working directory
os.chdir('/Users/ltraum/Documents/GitHub/AmericanPizzaProject')

# set api key
os.environ["OPENAI_API_KEY"] = "REPLACE W YOUR OWN"

#load data
data_path = "data/pizza_interviews.xlsx"
df = pd.read_excel(data_path)

# Preview data
print(df.columns)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       4 import os
#       5 import asyncio
# ----> 6 import pandas as pd
#       7 import text_lloom.workbench as wb
#      11 # Set working directory
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# Preprocess / slice dataset -> Experiment filtering input data to include only particular demographics and questions!

# %%
import sys, os
print("Python:", sys.executable)
print("VIRTUAL_ENV:", os.environ.get("VIRTUAL_ENV"))
# Out:
# Python: /opt/homebrew/opt/python@3.11/bin/python3.11
# VIRTUAL_ENV: /Users/ltraum/Documents/GitHub/AmericanPizzaProject/venv311

# %%
# Preprocess / slice data
# This filtering step needs work

def filter_demographics(
    df, regions=None, ages=None, income=None, diet=None
):
    df_filtered = df.copy()
    if regions:
        df_filtered = df_filtered[df_filtered["region_of_residence"].isin(regions)]
    if ages:
        df_filtered = df_filtered[df_filtered["age"].isin(ages)]
    if income:
        df_filtered = df_filtered[df_filtered["income"].isin(income)]
    if diet:
        df_filtered = df_filtered[df_filtered["food_restrictions"].isin(diet)]
    return df_filtered.reset_index(drop=True)

# Example: filter to just Northeast region
# filtered = filter_demographics(df, regions=['Northeast'], ages=['18-40'])
# filtered.head()

# %%
#all columns of interest
demo_cols = [
    "participant_id",
    "age",
    "city_of_residence",
    "state_of_residence",
    "region_of_residence",
    "income",
    "pizza_consumption",
    "food_restrictions"
]

# All response columns
response_cols = ["q1_response", "q2_response", "q3_response", "q4_response", "q5_response"]

# Add a column that concatenates all Q responses (handles missing by skipping blanks)
df["all_responses"] = df[response_cols].apply(
    lambda row: " ".join([str(r) for r in row if pd.notnull(r) and r.strip() != ""]),
    axis=1
)

# Build q_all_df with all demographics and the concatenated text
q_all_df = df[demo_cols + ["all_responses"]].rename(columns={"all_responses": "text"}) #toggle with responses included!
q_4_df = df[demo_cols + ["q4_response"]].rename(columns={"all_responses": "text"})

# Show the columns and a preview
print(q_all_df.columns)
q_all_df.head()
# Out:
# Index(['participant_id', 'age', 'city_of_residence', 'state_of_residence',
#        'region_of_residence', 'income', 'pizza_consumption',
#        'food_restrictions', 'text'],
#       dtype='object')
#    participant_id  age city_of_residence state_of_residence  \
# 0               1   32            Boston      Massachusetts
# 1               2   45           Atlanta            Georgia
# 2               3   67             Miami            Florida
# 3               4   23           Chicago           Illinois
# 4               5   41        Birmingham            Alabama
#
#   region_of_residence income       pizza_consumption     food_restrictions  \
# 0           Northeast   $65k                  Weekly  No food restrictions
# 1               South   $85k                 Monthly  No food restrictions
# 2               South   $45k  Occasionally eat pizza  No food restrictions
# 3             Midwest   $28k                  Weekly  No food restrictions
# 4               South   $52k                  Weekly    Lactose intolerant
#
#                                                 text
# 0  My big pizza moment was trying Regina's in the...
# 1  I wouldn't call it a turning point exactly. Gr...
# 2  My relationship with pizza has gone through ph...
# 3  I finally tried deep dish at Lou Malnati's sop...
# 4  Honestly, I haven't had some big pizza awakeni...

# %% [markdown]
# Induce themes with LLooM  -> Experiment inputting various seed theme terms!

# %%
# Prepare the lloom object
l = wb.lloom(q_all_df, text_col="text", id_col="participant_id")

async def extract_lloom_concepts(l, max_concepts=5, seed=""): 
    # Use gen_auto for one-step themes. seed is optional for steering.
    score_df = await l.gen_auto(max_concepts=max_concepts, seed=seed, debug=False)
    # Export: returns a summary per concept, ready for reporting
    export_df = l.export_df()
    return score_df, export_df

score_df, export_df = await extract_lloom_concepts(l, max_concepts=5, seed="convenience") #experiment adding stearing term like "taste" or "convenience" to seed
# Out:
# Estimated cost: $0.12
# **Please note that this is only an approximate cost estimate**
#
#
# Distill-filter
# ✅ Done
#
#
# Distill-summarize
# ✅ Done
#
#
# Cluster
# ✅ Done
#
#
# Synthesize
# ⠹ Loading
# /Users/ltraum/Documents/GitHub/AmericanPizzaProject/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /Users/ltraum/Documents/GitHub/AmericanPizzaProject/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ✅ Done
# ✅ Done with concept generation!
#
#
# Active concepts (n=5):
# - Family Gatherings: Does the text example describe pizza being used as a meal during family gatherings or events?
# - Convenience for Families: Does the text example emphasize pizza as a convenient meal option for busy families?
# - Family Gatherings: Does the text describe pizza being used as a central part of family gatherings or events?
# - Family Bonding: Does the text mention pizza as a means to enhance family bonding or shared experiences?
# - Nostalgic Family Memories: Does the text evoke nostalgic memories related to family and pizza?
#
#
# Scoring 5 concepts for 50 documents
# Estimated cost: $0.02
# **Please note that this is only an approximate cost estimate**
# 100%|██████████| 5/5 [00:44<00:00,  8.84s/it]
# ✅ Done with concept scoring!
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/GitHub/AmericanPizzaProject/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Family Gatherings'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 11
#       8     export_df = l.export_df()
#       9     return score_df, export_df
# ---> 11 score_df, export_df = await extract_lloom_concepts(l, max_concepts=5, seed="family") #add stearing term like "taste" or "convenience" to seed
#
# Cell In[41], line 8, in extract_lloom_concepts(l, max_concepts, seed)
#       6 score_df = await l.gen_auto(max_concepts=max_concepts, seed=seed, debug=False)
#       7 # Export: returns a summary per concept, ready for reporting
# ----> 8 export_df = l.export_df()
#       9 return score_df, export_df
#
# File ~/Documents/GitHub/AmericanPizzaProject/.venv/lib/python3.11/site-packages/text_lloom/workbench.py:772, in lloom.export_df(self, include_outliers)
#     771 def export_df(self, include_outliers=False):
# --> 772     return self.vis(export_df=True, include_outliers=include_outliers)
#
# File ~/Documents/GitHub/AmericanPizzaProject/.venv/lib/python3.11/site-packages/text_lloom/workbench.py:750, in lloom.vis(self, cols_to_show, slice_col, max_slice_bins, slice_bounds, show_highlights, norm_by, export_df, include_outliers)
#     747 active_concepts = self.__get_active_concepts()
#     748 score_df = self.get_score_df()
# --> 750 widget, matrix_df, item_df, item_df_wide = visualize(
#     751     in_df=self.in_df,
#     752     score_df=score_df,
#     753     doc_col=self.doc_col,
#     754     doc_id_col=self.doc_id_col,
#     755     score_col="score",
#     756     df_filtered=self.df_filtered,
#     757     df_bullets=self.df_bullets,
#     758     concepts=active_concepts,
#     759     cols_to_show=cols_to_show,
#     760     slice_col=slice_col,
#     761     max_slice_bins=max_slice_bins,
#     762     slice_bounds=slice_bounds,
#     763     show_highlights=show_highlights,
#     764     norm_by=norm_by,
#     765 )
#     766 if export_df:
#     767     return self.__get_df_for_export(item_df, include_outliers=include_outliers)
#
# File ~/Documents/GitHub/AmericanPizzaProject/.venv/lib/python3.11/site-packages/text_lloom/concept_induction.py:1377, in visualize(in_df, score_df, doc_col, doc_id_col, score_col, df_filtered, df_bullets, concepts, cols_to_show, slice_col, max_slice_bins, slice_bounds, show_highlights, norm_by, debug)
#    1376 def visualize(in_df, score_df, doc_col, doc_id_col, score_col, df_filtered, df_bullets, concepts, cols_to_show=[], slice_col=None, max_slice_bins=None, slice_bounds=None, show_highlights=False, norm_by=None, debug=False):
# -> 1377     matrix_df, item_df, item_df_wide, metadata_dict = prep_vis_dfs(in_df, score_df, doc_id_col, doc_col, score_col, df_filtered, df_bullets, concepts, cols_to_show=cols_to_show, slice_col=slice_col, max_slice_bins=max_slice_bins, slice_bounds=slice_bounds,show_highlights=show_highlights, norm_by=norm_by, debug=debug)
#    1379     data = matrix_df.to_json(orient='records')
#    1380     data_items = item_df.to_json(orient='records')
#
# File ~/Documents/GitHub/AmericanPizzaProject/.venv/lib/python3.11/site-packages/text_lloom/concept_induction.py:1183, in prep_vis_dfs(df, score_df, doc_id_col, doc_col, score_col, df_filtered, df_bullets, concepts, cols_to_show, slice_col, max_slice_bins, slice_bounds, show_highlights, norm_by, debug, threshold, outlier_threshold)
#    1181 slice_cts = {}
#    1182 concept_names = [c.name for c in concepts.values()]
# -> 1183 df["Outlier"] = [is_outlier(row, concept_names, outlier_threshold) for _, row in df.iterrows()]
#    1184 concept_names.append("Outlier")
#    1185 concept_cts["Outlier"] = sum(df["Outlier"])
#
# File ~/Documents/GitHub/AmericanPizzaProject/.venv/lib/python3.11/site-packages/text_lloom/concept_induction.py:1183, in <listcomp>(.0)
#    1181 slice_cts = {}
#    1182 concept_names = [c.name for c in concepts.values()]
# -> 1183 df["Outlier"] = [is_outlier(row, concept_names, outlier_threshold) for _, row in df.iterrows()]
#    1184 concept_names.append("Outlier")
#    1185 concept_cts["Outlier"] = sum(df["Outlier"])
#
# File ~/Documents/GitHub/AmericanPizzaProject/.venv/lib/python3.11/site-packages/text_lloom/concept_induction.py:1087, in is_outlier(row, concept_names, threshold)
#    1086 def is_outlier(row, concept_names, threshold):
# -> 1087     concept_matches = [clean_score(row[c], threshold) for c in concept_names]
#    1088     return not np.any(concept_matches)
#
# File ~/Documents/GitHub/AmericanPizzaProject/.venv/lib/python3.11/site-packages/text_lloom/concept_induction.py:1087, in <listcomp>(.0)
#    1086 def is_outlier(row, concept_names, threshold):
# -> 1087     concept_matches = [clean_score(row[c], threshold) for c in concept_names]
#    1088     return not np.any(concept_matches)
#
# File ~/Documents/GitHub/AmericanPizzaProject/.venv/lib/python3.11/site-packages/pandas/core/series.py:1130, in Series.__getitem__(self, key)
#    1127     return self._values[key]
#    1129 elif key_is_scalar:
# -> 1130     return self._get_value(key)
#    1132 # Convert generator to list before going through hashable part
#    1133 # (We will iterate through the generator there to check for slices)
#    1134 if is_iterator(key):
#
# File ~/Documents/GitHub/AmericanPizzaProject/.venv/lib/python3.11/site-packages/pandas/core/series.py:1246, in Series._get_value(self, label, takeable)
#    1243     return self._values[label]
#    1245 # Similar to Index.get_value, but we do not fall back to positional
# -> 1246 loc = self.index.get_loc(label)
#    1248 if is_integer(loc):
#    1249     return self._values[loc]
#
# File ~/Documents/GitHub/AmericanPizzaProject/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Family Gatherings'

# %%
# main outputs tables
print("Score DataFrame:")
display(score_df.head(10))
print("Exported Concepts/Themes:")
display(export_df.head(10))
# Out:
# Score DataFrame:
#   doc_id                                               text  \
# 0      1  Pizza is my social food - Friday nights with m...
# 1      2  Pizza is weekend or special occasion food for ...
# 2      3  Pizza is mostly about family time now.\nWhen g...
# 3      4  my roommate's parents took us to Lou's\nI'm a ...
# 4      5  Pizza is family dinner once or twice a week wh...
# 5      7  Pizza happens when the grandkids visit, mostly...
# 6      9  If my son visits with the grandkids, we might ...
# 7     11  My wife and I will pick a neighborhood and try...
# 8     13  Pizza is family dinner maybe once or twice a m...
# 9     14  it was an easy dinner solution and they loved ...
#
#                              concept_id    concept_name  \
# 0  8e2859c1-21b0-4f55-ac88-17abdb8e8798  Family Bonding
# 1  8e2859c1-21b0-4f55-ac88-17abdb8e8798  Family Bonding
# 2  8e2859c1-21b0-4f55-ac88-17abdb8e8798  Family Bonding
# 3  8e2859c1-21b0-4f55-ac88-17abdb8e8798  Family Bonding
# 4  8e2859c1-21b0-4f55-ac88-17abdb8e8798  Family Bonding
# 5  8e2859c1-21b0-4f55-ac88-17abdb8e8798  Family Bonding
# 6  8e2859c1-21b0-4f55-ac88-17abdb8e8798  Family Bonding
# 7  8e2859c1-21b0-4f55-ac88-17abdb8e8798  Family Bonding
# 8  8e2859c1-21b0-4f55-ac88-17abdb8e8798  Family Bonding
# 9  8e2859c1-21b0-4f55-ac88-17abdb8e8798  Family Bonding
#
#                                       concept_prompt  score  \
# 0  Does the text describe pizza as a means to enh...    1.0
# 1  Does the text describe pizza as a means to enh...    1.0
# 2  Does the text describe pizza as a means to enh...    1.0
# 3  Does the text describe pizza as a means to enh...    1.0
# 4  Does the text describe pizza as a means to enh...    1.0
# 5  Does the text describe pizza as a means to enh...    1.0
# 6  Does the text describe pizza as a means to enh...    1.0
# 7  Does the text describe pizza as a means to enh...    1.0
# 8  Does the text describe pizza as a means to enh...    1.0
# 9  Does the text describe pizza as a means to enh...    1.0
#
#                                            rationale  \
# 0  The text clearly describes pizza as a social f...
# 1  The text clearly describes pizza nights as a s...
# 2  The text clearly emphasizes the importance of ...
# 3  The text discusses how pizza brings the friend...
# 4  The text describes pizza as a regular family d...
# 5  The text emphasizes that pizza is primarily or...
# 6  The text discusses ordering pizza when family ...
# 7  The text describes a couple's shared experienc...
# 8  The text clearly describes pizza night as a sp...
# 9  The text emphasizes the nostalgic and social a...
#
#                                            highlight concept_seed
# 0  It's comfort food that brings people together ...       family
# 1          Pizza is a way to connect with my family.       family
# 2  Pizza nights with family are about conversatio...       family
# 3             Pizza brings our friend group together       family
# 4  Pizza is family dinner once or twice a week wh...       family
# 5    Pizza happens when the grandkids visit, mostly.       family
# 6  If my son visits with the grandkids, we might ...       family
# 7  My wife and I will pick a neighborhood and try...       family
# 8  It's comfort food that brings the family toget...       family
# 9  It's more about the memories and family time t...       family
# Exported Concepts/Themes:
#               concept                                           criteria  \
# 0      Family Bonding  Does the text describe pizza as a means to enh...
# 1   Family Gatherings  Is pizza described as a common food choice for...
# 2    Family Occasions  Is pizza mentioned as a food associated with s...
# 3  Family Preferences  Does the text discuss specific pizza preferenc...
# 4   Family Traditions  Does the text mention pizza as part of a famil...
#
#                                              summary  \
# 0  Pizza fosters family bonding, creating cherish...
# 1  Pizza is a beloved family meal, often enjoyed ...
# 2  Pizza is a cherished family tradition, often e...
# 3  Pizza is a family favorite, often chosen for g...
# 4  Family traditions revolve around pizza nights,...
#
#                                         rep_examples  prevalence  n_matches  \
# 0  [Pizza is my social food - Friday nights with ...        0.48         24
# 1  [The city has good neighborhood spots that wor...        0.48         24
# 2  [it was an easy dinner solution and they loved...        0.34         17
# 3  [Pizza is family dinner once or twice a week w...        0.48         24
# 4  [If my son visits with the grandkids, we might...        0.36         18
#
#                                           highlights
# 0  [Pizza is family dinner maybe once or twice a ...
# 1  [If my son visits with the grandkids, we might...
# 2  [Pizza happens maybe once every couple months,...
# 3  [It's also easy dinner when both parents are w...
# 4  [Pizza nights with family are about conversati...

# %%
# report per-theme results for future app
for i, row in export_df.iterrows():
    print(f"\nTheme {i+1}: {row['concept']}")
    print(f"Criteria: {row['criteria']}")
    print(f"Summary: {row['summary']}")
    print(f"Prevalence: {row['prevalence']*100:.1f}% of participants")
    print("Representative Examples:")
    for ex in row['rep_examples']:
        print("-", ex)
    print("-" * 40)

# Save results to CSV for future dashboard use
export_df.to_csv("lloom_themes_summary.csv", index=False)
score_df.to_csv("lloom_theme_scores.csv", index=False)
# Out:
# Theme 1: Family Bonding
# Criteria: Does the text describe pizza as a means to enhance family bonding or togetherness?
# Summary: Pizza fosters family bonding, creating cherished memories and connections during casual meals and gatherings.
# Prevalence: 48.0% of participants
# Representative Examples:
# - Pizza is my social food - Friday nights with my girlfriend watching movies, or hitting spots in the North End with friends before Red Sox games.
# I rarely eat it alone or on-the-go.
# It's comfort food that brings people together and forces us to slow down during busy weeks.
# Weekend afternoons we'll walk to our local place and sit outside with slices and beers.
# - Pizza is Lions game food, family gatherings, and weekend comfort.
# During football season, Buddy's delivery is basically mandatory for watching games.
# It's also celebration food - promotions, birthdays, good news gets celebrated with Detroit square pizza.
# Sunday dinner with extended family often includes picking up squares from our favorite spots.
# It's social food that brings people together and represents Detroit pride.
# I probably eat it twice a week, sometimes more during football season.
# The presentation is part of the experience - seeing those perfect squares with caramelized edges.
# I eat it with my hands mostly, though sometimes you need a fork for the really cheesy bites.
# The crispy edges give you good grip points.
# It's heartier than thin crust so utensils aren't shameful like they would be for New York pizza.
# The biggest barrier is that most places outside Detroit don't make real Detroit-style pizza, even when they claim to.
# When I travel for work, I'm constantly disappointed by 'Detroit-style' that's just thick crust with sauce on top.
# The pans, the cheese, the technique - it all matters.
# Cost can be a factor since good Detroit pizza is substantial and priced accordingly.
# During economic downturns in the city, some longtime places have struggled or closed, which breaks my heart.
# I grew up on Buddy's and Loui's, thinking that square pizza with crispy cheese edges was normal.
# Coming back home, I appreciate even more how special our pizza culture is.
# Authentic Detroit square - thick, airy crust that's crispy on the bottom from those blue steel pans.
# Pepperoni that cups up when it cooks.
# ----------------------------------------
#
# Theme 2: Family Gatherings
# Criteria: Is pizza described as a common food choice for family gatherings or events?
# Summary: Pizza is a beloved family meal, often enjoyed during gatherings, special occasions, and visits from grandchildren.
# Prevalence: 48.0% of participants
# Representative Examples:
# - The city has good neighborhood spots that work for everything from family dinners to drinks with friends.
# I eat pizza maybe twice a month, usually in social settings or when entertaining.
# Richmond's laid-back culture suits pizza well - it's unpretentious food that brings people together.
# Good for everything from kid birthday parties to casual date nights.
# - The Mormon culture here also means lots of family-focused restaurants that do pizza well.
# I eat pizza weekly, often with friends after activities or as casual dinner.
# Utah pizza places tend to be pretty casual and family-friendly.
# The focus is on substance and value rather than fancy presentation.
# Salt Lake has good pizza availability and reasonable prices.
# ----------------------------------------
#
# Theme 3: Family Occasions
# Criteria: Is pizza mentioned as a food associated with special family occasions or celebrations?
# Summary: Pizza is a cherished family tradition, often enjoyed during special occasions and gatherings, creating lasting memories together.
# Prevalence: 34.0% of participants
# Representative Examples:
# - it was an easy dinner solution and they loved it.
# Now that they're grown and moved out, my husband and I rarely order pizza.
# when the grandkids visit or if we're feeling nostalgic.
# It's more about the memories and family time than the actual food these days.
# Pizza happens maybe once every couple months, usually when we're babysitting the grandkids or having a casual family gathering.
# It's nostalgic food that reminds me of easier times when the kids were small and pizza night was a weekly tradition.
# Sometimes my husband and I will split a small pizza while watching a movie, but that's rare.
# When we do eat pizza, it's more about the social aspect and memories than satisfying a craving.
# It represents family time and simpler pleasures.
# I always transfer pizza to proper plates - eating from boxes feels messy and informal.
# Maybe that's old-fashioned, but I prefer sitting at the table with real dinnerware.
# Good manners matter, even with casual food.
# The presentation affects my enjoyment of the meal.
# The main barrier now is that pizza often feels too heavy or rich for my current appetite and digestion.
# What I could easily eat at 40 now seems like too much food.
# Sometimes I want pizza but know I'll regret it later, so I'll make a lighter dinner instead.
# finding pizza that suits my current preferences - lighter, less greasy - can be challenging since most places cater to younger appetites.
# my husband and I rarely order pizza.
# when the grandkids visit or if we're feeling nostalgic.
# - When family visits from out of state, we always take them to Pepe's or Sally's to experience real Connecticut pizza.
# I eat it maybe once a month, usually as a cultural experience rather than just dinner.
# It's something you plan around - waiting in line, making it an event.
# Connecticut pizza isn't just food, it's heritage.
# We take friends there to prove our state has good food culture too.
# ----------------------------------------
#
# Theme 4: Family Preferences
# Criteria: Does the text discuss specific pizza preferences or choices made to accommodate family members?
# Summary: Pizza is a family favorite, often chosen for gatherings, kids' preferences, and ease of preparation.
# Prevalence: 48.0% of participants
# Representative Examples:
# - Pizza is family dinner once or twice a week when nobody wants to cook.
# Usually Friday nights or busy weeknights when we're all running around with kids' activities.
# We order two large pizzas - cheese for the kids, pepperoni for adults.
# It's easy, everyone's happy, and no dishes to wash.
# Pizza is practical food for busy families.
# Pizza boxes are fine - they do the job and kids think eating from boxes is fun.
# Makes cleanup easier too.
# I eat pizza with my hands like a normal person.
# Pizza is casual food that should be eaten casually.
# Boxes and hands keep it simple, which is how pizza should be.
# Lactose intolerance is my main barrier now.
# Not every place offers dairy-free cheese, and when they do, it often costs extra which is annoying.
# Some places the fake cheese tastes terrible or has weird texture.
# Chain places are usually better about dairy-free options than local spots.
# Cost sometimes factors in - feeding a family of four with pizza can hit $40-50.
# But overall, pizza is pretty accessible in Birmingham.
# I've liked pizza since I was a kid and my preferences haven't changed much.
# I still think Pizza Hut makes decent pizza - it's consistent and my kids like it.
# Pizza is supposed to be simple comfort food, not some fancy culinary experience.
# - families always get half plain cheese for kids
# I learned to judge pizza places by how they treat their drivers and how the kitchen looks
# I still eat pizza regularly, but I'm pickier about where I order from
# It's weird being on the customer side now after years of delivering
# Pizza is convenient dinner food
# I tip drivers really well because I know how hard that job is
# Having delivered thousands of pizzas, I know boxes are crucial for temperature and presentation
# Good pizzerias invest in proper packaging
# I eat with my hands like everyone else
# I notice details like grease levels and structural integrity more than I used to
# Working in pizza made me appreciate the technical aspects most customers never think about
# My biggest advantage is knowing which places to avoid
# I've seen behind the scenes at too many sketchy operations
# Cost isn't usually an issue since I know where to get good value
# The main barrier now is that I'm probably too critical
# It's hard to just enjoy pizza without analyzing the quality
# Sometimes knowledge ruins the simple pleasure of just eating pizza
# Wealthy areas order fancy toppings and tip well
# College areas want cheap and filling
# My ideal slice has hand-stretched dough, good tomato sauce, real mozzarella
# ----------------------------------------
#
# Theme 5: Family Traditions
# Criteria: Does the text mention pizza as part of a family tradition or regular family activity?
# Summary: Family traditions revolve around pizza nights, fostering connection, conversation, and shared experiences during casual meals together.
# Prevalence: 36.0% of participants
# Representative Examples:
# - If my son visits with the grandkids, we might order pizza for dinner.
# It's become less frequent as I've gotten older - doesn't sit as well as it used to.
# When I do eat it, I prefer sitting down at the actual pizzeria rather than delivery.
# I remember when pizza came wrapped in paper, not boxes.
# The main barrier now is that many of my old favorite places have closed or changed ownership.
# The neighborhood spots that made real tomato pie are disappearing.
# Sometimes I want that specific South Philly tomato pie but have to settle for regular pizza because the authentic places are harder to find.
# - I eat it less frequently now, maybe once a month, usually when grandchildren visit and want something familiar.
# Pizza is mainly about spending time with family now.
# When the grandkids visit, we'll often go to Regina's or order from a local place.
# It's one of the few foods that spans generations - they get excited about pizza, and I enjoy watching them experience places that have been part of Boston for decades.
# I rarely eat pizza outside of family occasions.
# It's become more about tradition and memories than regular dining.
# I remember when pizza came wrapped in paper from places like Regina's.
# Even at 74, I can handle a slice just fine.
# Many of my old favorite places have closed or changed ownership over the years.
# The North End has become touristy and expensive, so authentic neighborhood spots are harder to find.
# Sometimes I want that specific old-school Boston pizza but have to settle for places that aren't quite right.
# The biggest barrier is that pizza culture has moved away from its roots - it's become fancy food instead of honest, affordable comfort food.
# I want pizza that tastes like it did in the old neighborhood, made by people who learned from their grandmothers.
# Simple toppings - maybe pepperoni or sausage, but often just cheese is perfect.
# The crust should have good chew and those nice air bubbles from proper fermentation.
# Places like Regina's or Santarpio's represent what pizza should be to me.
# But I eat it less frequently now, maybe once a month, usually when grandchildren visit and want something familiar.
# I always eat with my hands - that's how pizza was meant to be consumed.
# Using utensils seems pretentious and disconnected from pizza's working-class roots.
# Back then, pizza was simpler and cheaper - Regina's, Santarpio's, places like that served working-class neighborhoods.
# ----------------------------------------

# %%
#l.vis()
l.vis(slice_col="region_of_residence")
# Out:
# MatrixWidget(data='[{"id":"All","value":24,"example":"All","_my_score":0,"concept":"Family Bonding","n":24},{"…
